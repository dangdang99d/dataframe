# %%
import pandas as pd
airbnb_df =pd.read_csv('airbnb.csv')
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  MASSACHUSETTS       4     1     Apartment     NaN          0
# 2    OZ5857       ILLINOIS       4     3     Apartment   100.0         51
# 3    HY8797     california       2     1     Apartment    75.0          4
# 4    VN7858  massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     california       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       ILLINOIS       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price
# ...

# %%
airbnb_df['state'].unique() # state컬럼의 유니크한 값을 볼 수 있다. 그러나  대문자 소문자만 다르게 중복된
# 문자들이 있다.
# Out:
# array(['Illinois', 'MASSACHUSETTS', 'ILLINOIS', 'california',
#        'massachusetts', 'California', 'Massachusetts', 'CALIFORNIA',
#        'illinois'], dtype=object)

# %%
airbnb_df['state'].str.lower() #소문자
#모든 글자를 대문자 혹은 소문자로 통일한 후 중복성을 체크한다.
# Out:
# 0           illinois
# 1      massachusetts
# 2           illinois
# 3         california
# 4      massachusetts
#            ...
# 708       california
# 709       california
# 710       california
# 711         illinois
# 712    massachusetts
# Name: state, Length: 713, dtype: object

# %%
airbnb_df['state'].str.capitalize() #첫 글자만 대문자
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  MASSACHUSETTS       4     1     Apartment     NaN          0
# 2    OZ5857       ILLINOIS       4     3     Apartment   100.0         51
# 3    HY8797     california       2     1     Apartment    75.0          4
# 4    VN7858  massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     california       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       ILLINOIS       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price
# ...

# %% [markdown]
# # 문자열 분리하기
# # loacation 은 ,기준으로 split해보자

# %%
airbnb_df['neighborhood']=airbnb_df['location'].str.split(',').str[0] #,를 기준으로 split 각 시리즈에서
#0번째 값을 추출 리스트 접근할 때도 str써야하는거 주의함

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  MASSACHUSETTS       4     1     Apartment     NaN          0
# 2    OZ5857       ILLINOIS       4     3     Apartment   100.0         51
# 3    HY8797     california       2     1     Apartment    75.0          4
# 4    VN7858  massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     california       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       ILLINOIS       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price   neighborhood
# ...

# %%
airbnb_df[airbnb_df['neighborhood']=='Venice']
# Out:
#          id       state  guests  beds property_type  rating  n_reviews  \
# 82   ZN9465  CALIFORNIA       1     1     Apartment    99.0         54
# 96   CJ7504  california       2     1         House    90.0         31
# 119  PB4847  California       5     2     Apartment    98.0         42
# 207  CB6890  California       4     2     Apartment   100.0          2
# 208  PL4100  California       4     1     Apartment    95.0          4
# 221  HM2399  California       2     1     Apartment    94.0         16
# 223  FJ2698  california       3     2         House    94.0        183
# 280  GX4621  california       2     1     Apartment   100.0          1
# 282  TM7390  california       4     3     Apartment    91.0        110
# 409  KW4349  California       2     1     Apartment   100.0          4
# 578  TL9265  california       2     2         House    98.0          9
# 583  TT4738  california       3     2         Other    92.0         31
# ...

# %% [markdown]
# # strip 사용하여 공백 제거 하기 중요함!!
# ## 혹은 replace를 통해 제거도 가능하다.
# # str.replace('.','',regex=False) .을 없애버린다.
# # regex기본값이 true로 되어 있으며 패턴을 찾아 없앤다. 그런데 이번 .을 찾아서 없애는 것이기 때문에 regex= Fasle를 한다.
